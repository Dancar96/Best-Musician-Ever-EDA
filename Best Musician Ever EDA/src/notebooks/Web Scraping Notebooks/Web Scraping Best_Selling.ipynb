# %% [markdown]
# # Web Scraping a la página de Chartmasters

# %% [markdown]
# URL: "https://chartmasters.org/best-selling-artists-of-all-time/"

# %% [markdown]
# Se realiza Web Scraping con Beautiful Soup a la página de Chartmasters para extraer un DataFrame sobre los artistas que más han vendido.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Hacemos la petición HTTP
url = "https://chartmasters.org/best-selling-artists-of-all-time/"
response = requests.get(url)

# Parseamos el HTML con BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Obtenemos la tabla con la información requerida
table = soup.find("table", {"class": "resultsTab"})

# Creamos una lista vacía para almacenar los datos de cada fila
data = []

# Recorremos todas las filas de la tabla y extraemos la información de las columnas
for row in table.find_all("tr")[1:]:
    cells = row.find_all("td")
    artist = cells[2].text.strip()
    total_cspc = cells[3].text.strip()
    studio_albums_sales = cells[4].text.strip()
    other_lps_sales = cells[5].text.strip()
    physical_singles_sales = cells[6].text.strip()
    digital_singles_sales = cells[7].text.strip()
    sales_update = cells[8].text.strip()
    streams_eas_update = cells[9].text.strip()
    
    # Añadimos los datos de la fila a la lista
    data.append({
        "Artist": artist,
        "Total CSPC": total_cspc,
        "Studio Albums Sales": studio_albums_sales,
        "Other LPs Sales": other_lps_sales,
        "Physical Singles Sales": physical_singles_sales,
        "Digital Singles Sales": digital_singles_sales,
        "Sales Update": sales_update,
        "Streams EAS (Update)": streams_eas_update
    })

# %%
data
# Out:
# [{'Artist': 'The Beatles',
#   'Total CSPC': '421,855,000',
#   'Studio Albums Sales': '160,650,000',
#   'Other LPs Sales': '203,392,000',
#   'Physical Singles Sales': '116,080,000'},
#  {'Artist': 'Michael Jackson',
#   'Total CSPC': '336,644,000',
#   'Studio Albums Sales': '182,600,000',
#   'Other LPs Sales': '101,997,000',
#   'Physical Singles Sales': '79,350,000'},
#  {'Artist': 'Elvis Presley',
#   'Total CSPC': '320,348,000',
#   'Studio Albums Sales': '53,150,000',
#   'Other LPs Sales': '212,309,000',
#   'Physical Singles Sales': '135,210,000'},
#  {'Artist': 'Queen',
#   'Total CSPC': '277,454,000',
#   'Studio Albums Sales': '90,230,000',
#   'Other LPs Sales': '139,348,000',
#   'Physical Singles Sales': '49,960,000'},
#  {'Artist': 'Madonna',
#   'Total CSPC': '246,817,000',
#   'Studio Albums Sales': '146,450,000',
#   'Other LPs Sales': '64,420,000',
#   'Physical Singles Sales': '75,210,000'},
#  {'Artist': 'The Rolling Stones',
#   'Total CSPC': '243,426,000',
#   'Studio Albums Sales': '113,800,000',
#   'Other LPs Sales': '92,495,000',
#   'Physical Singles Sales': '72,770,000'},
#  {'Artist': 'Pink Floyd',
#   'Total CSPC': '237,034,000',
#   'Studio Albums Sales': '169,600,000',
#   'Other LPs Sales': '52,025,000',
#   'Physical Singles Sales': '8,800,000'},
#  {'Artist': 'Frank Sinatra',
#   'Total CSPC': '228,897,000',
#   'Studio Albums Sales': '49,571,000',
#   'Other LPs Sales': '139,858,000',
#   'Physical Singles Sales': '95,250,000'},
#  {'Artist': 'Elton John',
#   'Total CSPC': '222,173,000',
#   'Studio Albums Sales': '88,630,000',
#   'Other LPs Sales': '82,400,000',
#   'Physical Singles Sales': '80,920,000'},
#  {'Artist': 'Led Zeppelin',
#   'Total CSPC': '206,466,000',
#   'Studio Albums Sales': '141,500,000',
#   'Other LPs Sales': '51,200,000',
#   'Physical Singles Sales': '6,350,000'},
#  {'Artist': 'Eminem',
#   'Total CSPC': '202,372,000',
#   'Studio Albums Sales': '98,650,000',
#   'Other LPs Sales': '26,757,000',
#   'Physical Singles Sales': '14,320,000'},
#  {'Artist': 'U2',
#   'Total CSPC': '200,556,000',
#   'Studio Albums Sales': '127,100,000',
#   'Other LPs Sales': '53,051,000',
#   'Physical Singles Sales': '22,550,000'},
#  {'Artist': 'AC/DC',
#   'Total CSPC': '200,529,000',
#   'Studio Albums Sales': '132,470,000',
#   'Other LPs Sales': '49,349,000',
#   'Physical Singles Sales': '7,200,000'},
#  {'Artist': 'Céline Dion',
#   'Total CSPC': '198,648,000',
#   'Studio Albums Sales': '136,200,000',
#   'Other LPs Sales': '40,424,000',
#   'Physical Singles Sales': '39,290,000'},
#  {'Artist': 'Rod Stewart & Faces',
#   'Total CSPC': '190,822,000',
#   'Studio Albums Sales': '100,150,000',
#   'Other LPs Sales': '66,819,000',
#   'Physical Singles Sales': '55,220,000'},
#  {'Artist': 'Mariah Carey',
#   'Total CSPC': '176,263,000',
#   'Studio Albums Sales': '116,100,000',
#   'Other LPs Sales': '31,228,000',
#   'Physical Singles Sales': '36,890,000'},
#  {'Artist': 'Eagles',
#   'Total CSPC': '175,554,000',
#   'Studio Albums Sales': '65,425,000',
#   'Other LPs Sales': '96,732,000',
#   'Physical Singles Sales': '16,630,000'},
#  {'Artist': 'Eric Clapton',
#   'Total CSPC': '175,204,000',
#   'Studio Albums Sales': '73,510,000',
#   'Other LPs Sales': '85,088,000',
#   'Physical Singles Sales': '29,940,000'},
#  {'Artist': 'Metallica',
#   'Total CSPC': '169,970,000',
#   'Studio Albums Sales': '121,260,000',
#   'Other LPs Sales': '20,164,000',
#   'Physical Singles Sales': '15,480,000'},
#  {'Artist': 'ABBA',
#   'Total CSPC': '162,924,000',
#   'Studio Albums Sales': '45,300,000',
#   'Other LPs Sales': '91,491,000',
#   'Physical Singles Sales': '54,400,000'},
#  {'Artist': 'Bee Gees',
#   'Total CSPC': '161,865,000',
#   'Studio Albums Sales': '75,525,000',
#   'Other LPs Sales': '56,477,000',
#   'Physical Singles Sales': '72,790,000'},
#  {'Artist': 'Bruce Springsteen',
#   'Total CSPC': '161,356,000',
#   'Studio Albums Sales': '103,400,000',
#   'Other LPs Sales': '42,176,000',
#   'Physical Singles Sales': '21,010,000'},
#  {'Artist': 'Whitney Houston',
#   'Total CSPC': '157,980,000',
#   'Studio Albums Sales': '113,600,000',
#   'Other LPs Sales': '17,175,000',
#   'Physical Singles Sales': '49,520,000'},
#  {'Artist': 'Barbra Streisand',
#   'Total CSPC': '153,502,000',
#   'Studio Albums Sales': '91,370,000',
#   'Other LPs Sales': '49,714,000',
#   'Physical Singles Sales': '35,250,000'},
#  {'Artist': 'Phil Collins',
#   'Total CSPC': '151,851,000',
#   'Studio Albums Sales': '93,780,000',
#   'Other LPs Sales': '39,905,000',
#   'Physical Singles Sales': '29,910,000'},
#  {'Artist': 'Fleetwood Mac',
#   'Total CSPC': '151,752,000',
#   'Studio Albums Sales': '84,550,000',
#   'Other LPs Sales': '46,392,000',
#   'Physical Singles Sales': '26,060,000'},
#  {'Artist': 'Bon Jovi',
#   'Total CSPC': '151,115,000',
#   'Studio Albums Sales': '89,450,000',
#   'Other LPs Sales': '39,176,000',
#   'Physical Singles Sales': '27,980,000'},
#  {'Artist': 'Billy Joel',
#   'Total CSPC': '150,914,000',
#   'Studio Albums Sales': '91,400,000',
#   'Other LPs Sales': '40,235,000',
#   'Physical Singles Sales': '36,900,000'},
#  {'Artist': 'Santana',
#   'Total CSPC': '146,371,000',
#   'Studio Albums Sales': '89,465,000',
#   'Other LPs Sales': '46,265,000',
#   'Physical Singles Sales': '15,380,000'},
#  {'Artist': 'Bob Dylan',
#   'Total CSPC': '145,073,000',
#   'Studio Albums Sales': '83,350,000',
#   'Other LPs Sales': '47,870,000',
#   'Physical Singles Sales': '17,680,000'},
#  {'Artist': 'Garth Brooks',
#   'Total CSPC': '144,490,000',
#   'Studio Albums Sales': '81,605,000',
#   'Other LPs Sales': '62,341,000',
#   'Physical Singles Sales': '950,000'},
#  {'Artist': 'Bob Marley',
#   'Total CSPC': '142,719,000',
#   'Studio Albums Sales': '43,075,000',
#   'Other LPs Sales': '81,593,000',
#   'Physical Singles Sales': '9,980,000'},
#  {'Artist': 'Taylor Swift',
#   'Total CSPC': '142,315,000',
#   'Studio Albums Sales': '53,755,000',
#   'Other LPs Sales': '9,393,000',
#   'Physical Singles Sales': '350,000'},
#  {'Artist': 'Prince',
#   'Total CSPC': '134,123,000',
#   'Studio Albums Sales': '86,580,000',
#   'Other LPs Sales': '27,141,000',
#   'Physical Singles Sales': '42,910,000'},
#  {'Artist': 'Aerosmith',
#   'Total CSPC': '133,912,000',
#   'Studio Albums Sales': '71,710,000',
#   'Other LPs Sales': '48,158,000',
#   'Physical Singles Sales': '15,500,000'},
#  {'Artist': 'David Bowie',
#   'Total CSPC': '131,301,000',
#   'Studio Albums Sales': '71,500,000',
#   'Other LPs Sales': '36,023,000',
#   'Physical Singles Sales': '44,200,000'},
#  {'Artist': 'Simon & Garfunkel',
#   'Total CSPC': '126,354,000',
#   'Studio Albums Sales': '37,820,000',
#   'Other LPs Sales': '75,732,000',
#   'Physical Singles Sales': '23,830,000'},
#  {'Artist': "Guns N' Roses",
#   'Total CSPC': '125,641,000',
#   'Studio Albums Sales': '86,360,000',
#   'Other LPs Sales': '20,134,000',
#   'Physical Singles Sales': '11,900,000'},
#  {'Artist': 'Stevie Wonder',
#   'Total CSPC': '124,341,000',
#   'Studio Albums Sales': '65,605,000',
#   'Other LPs Sales': '28,070,000',
#   'Physical Singles Sales': '65,320,000'},
#  {'Artist': 'The Doors',
#   'Total CSPC': '117,290,000',
#   'Studio Albums Sales': '51,980,000',
#   'Other LPs Sales': '55,480,000',
#   'Physical Singles Sales': '13,860,000'},
#  {'Artist': 'BTS',
#   'Total CSPC': '115,500,000',
#   'Studio Albums Sales': '31,845,000',
#   'Other LPs Sales': '17,015,000',
#   'Physical Singles Sales': '7,290,000'},
#  {'Artist': 'Genesis',
#   'Total CSPC': '113,956,000',
#   'Studio Albums Sales': '78,400,000',
#   'Other LPs Sales': '28,082,000',
#   'Physical Singles Sales': '13,910,000'},
#  {'Artist': 'Coldplay',
#   'Total CSPC': '113,224,000',
#   'Studio Albums Sales': '60,160,000',
#   'Other LPs Sales': '6,090,000',
#   'Physical Singles Sales': '2,060,000'},
#  {'Artist': 'Britney Spears',
#   'Total CSPC': '113,106,000',
#   'Studio Albums Sales': '68,595,000',
#   'Other LPs Sales': '11,460,000',
#   'Physical Singles Sales': '18,600,000'},
#  {'Artist': 'Paul McCartney',
#   'Total CSPC': '112,665,000',
#   'Studio Albums Sales': '61,670,000',
#   'Other LPs Sales': '27,441,000',
#   'Physical Singles Sales': '57,970,000'},
#  {'Artist': 'Dire Straits',
#   'Total CSPC': '112,036,000',
#   'Studio Albums Sales': '71,730,000',
#   'Other LPs Sales': '31,635,000',
#   'Physical Singles Sales': '8,380,000'},
#  {'Artist': 'Drake',
#   'Total CSPC': '110,954,000',
#   'Studio Albums Sales': '15,525,000',
#   'Other LPs Sales': '80,000',
#   'Physical Singles Sales': '40,000'},
#  {'Artist': 'George Michael & Wham!',
#   'Total CSPC': '110,045,000',
#   'Studio Albums Sales': '60,200,000',
#   'Other LPs Sales': '26,150,000',
#   'Physical Singles Sales': '49,880,000'},
#  {'Artist': 'Rihanna',
#   'Total CSPC': '106,145,000',
#   'Studio Albums Sales': '33,480,000',
#   'Other LPs Sales': '1,265,000',
#   'Physical Singles Sales': '3,600,000'},
#  {'Artist': 'Jimi Hendrix',
#   'Total CSPC': '105,789,000',
#   'Studio Albums Sales': '29,330,000',
#   'Other LPs Sales': '69,219,000',
#   'Physical Singles Sales': '6,210,000'},
#  {'Artist': 'Adele',
#   'Total CSPC': '104,623,000',
#   'Studio Albums Sales': '63,375,000',
#   'Other LPs Sales': '4,133,000',
#   'Physical Singles Sales': '570,000'},
#  {'Artist': 'Van Halen',
#   'Total CSPC': '102,491,000',
#   'Studio Albums Sales': '79,620,000',
#   'Other LPs Sales': '14,065,000',
#   'Physical Singles Sales': '10,450,000'},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Total CSPC': '101,524,000',
#   'Studio Albums Sales': '61,870,000',
#   'Other LPs Sales': '16,881,000',
#   'Physical Singles Sales': '4,800,000'},
#  {'Artist': 'The Police',
#   'Total CSPC': '99,857,000',
#   'Studio Albums Sales': '46,370,000',
#   'Other LPs Sales': '40,183,000',
#   'Physical Singles Sales': '23,810,000'},
#  {'Artist': 'Backstreet Boys',
#   'Total CSPC': '99,240,000',
#   'Studio Albums Sales': '58,900,000',
#   'Other LPs Sales': '25,685,000',
#   'Physical Singles Sales': '18,010,000'},
#  {'Artist': 'Neil Young',
#   'Total CSPC': '99,113,000',
#   'Studio Albums Sales': '65,210,000',
#   'Other LPs Sales': '21,443,000',
#   'Physical Singles Sales': '14,030,000'},
#  {'Artist': 'Nirvana',
#   'Total CSPC': '97,343,000',
#   'Studio Albums Sales': '45,000,000',
#   'Other LPs Sales': '37,650,000',
#   'Physical Singles Sales': '4,190,000'},
#  {'Artist': 'Justin Bieber',
#   'Total CSPC': '95,077,000',
#   'Studio Albums Sales': '20,725,000',
#   'Other LPs Sales': '8,104,000',
#   'Physical Singles Sales': '730,000'},
#  {'Artist': 'Creedence Clearwater Revival',
#   'Total CSPC': '94,069,000',
#   'Studio Albums Sales': '33,135,000',
#   'Other LPs Sales': '45,489,000',
#   'Physical Singles Sales': '22,570,000'},
#  {'Artist': 'Beyonce',
#   'Total CSPC': '93,824,000',
#   'Studio Albums Sales': '37,140,000',
#   'Other LPs Sales': '5,946,000',
#   'Physical Singles Sales': '3,970,000'},
#  {'Artist': 'Ed Sheeran',
#   'Total CSPC': '93,570,000',
#   'Studio Albums Sales': '23,160,000',
#   'Other LPs Sales': '1,343,000',
#   'Physical Singles Sales': '180,000'},
#  {'Artist': 'Linkin Park',
#   'Total CSPC': '93,299,000',
#   'Studio Albums Sales': '48,350,000',
#   'Other LPs Sales': '14,500,000',
#   'Physical Singles Sales': '3,210,000'},
#  {'Artist': 'Deep Purple',
#   'Total CSPC': '93,120,000',
#   'Studio Albums Sales': '45,485,000',
#   'Other LPs Sales': '40,666,000',
#   'Physical Singles Sales': '12,180,000'},
#  {'Artist': 'R.E.M.',
#   'Total CSPC': '90,868,000',
#   'Studio Albums Sales': '66,685,000',
#   'Other LPs Sales': '16,347,000',
#   'Physical Singles Sales': '8,280,000'},
#  {'Artist': 'Green Day',
#   'Total CSPC': '90,285,000',
#   'Studio Albums Sales': '58,250,000',
#   'Other LPs Sales': '13,567,000',
#   'Physical Singles Sales': '3,050,000'},
#  {'Artist': 'Bryan Adams',
#   'Total CSPC': '89,753,000',
#   'Studio Albums Sales': '42,260,000',
#   'Other LPs Sales': '30,518,000',
#   'Physical Singles Sales': '32,090,000'},
#  {'Artist': 'Iron Maiden',
#   'Total CSPC': '89,126,000',
#   'Studio Albums Sales': '56,820,000',
#   'Other LPs Sales': '25,526,000',
#   'Physical Singles Sales': '4,640,000'},
#  {'Artist': 'Enya',
#   'Total CSPC': '88,870,000',
#   'Studio Albums Sales': '65,480,000',
#   'Other LPs Sales': '17,069,000',
#   'Physical Singles Sales': '5,250,000'},
#  {'Artist': 'Shania Twain',
#   'Total CSPC': '83,064,000',
#   'Studio Albums Sales': '63,200,000',
#   'Other LPs Sales': '11,259,000',
#   'Physical Singles Sales': '13,130,000'},
#  {'Artist': '2Pac',
#   'Total CSPC': '82,720,000',
#   'Studio Albums Sales': '46,290,000',
#   'Other LPs Sales': '17,136,000',
#   'Physical Singles Sales': '11,920,000'},
#  {'Artist': 'Journey',
#   'Total CSPC': '82,698,000',
#   'Studio Albums Sales': '40,250,000',
#   'Other LPs Sales': '31,623,000',
#   'Physical Singles Sales': '8,090,000'},
#  {'Artist': 'Maroon 5',
#   'Total CSPC': '82,562,000',
#   'Studio Albums Sales': '26,050,000',
#   'Other LPs Sales': '2,138,000',
#   'Physical Singles Sales': '1,600,000'},
#  {'Artist': 'Sting',
#   'Total CSPC': '81,555,000',
#   'Studio Albums Sales': '52,360,000',
#   'Other LPs Sales': '17,720,000',
#   'Physical Singles Sales': '16,010,000'},
#  {'Artist': 'P!nk',
#   'Total CSPC': '80,517,000',
#   'Studio Albums Sales': '41,910,000',
#   'Other LPs Sales': '10,590,000',
#   'Physical Singles Sales': '7,700,000'},
#  {'Artist': 'Black Sabbath',
#   'Total CSPC': '79,831,000',
#   'Studio Albums Sales': '46,280,000',
#   'Other LPs Sales': '27,467,000',
#   'Physical Singles Sales': '3,420,000'},
#  {'Artist': 'Lady Gaga',
#   'Total CSPC': '79,259,000',
#   'Studio Albums Sales': '31,215,000',
#   'Other LPs Sales': '4,790,000',
#   'Physical Singles Sales': '1,570,000'},
#  {'Artist': 'Janet Jackson',
#   'Total CSPC': '78,406,000',
#   'Studio Albums Sales': '50,500,000',
#   'Other LPs Sales': '12,175,000',
#   'Physical Singles Sales': '40,640,000'},
#  {'Artist': 'Robbie Williams',
#   'Total CSPC': '77,556,000',
#   'Studio Albums Sales': '46,500,000',
#   'Other LPs Sales': '21,770,000',
#   'Physical Singles Sales': '11,960,000'},
#  {'Artist': 'Bruno Mars',
#   'Total CSPC': '76,717,000',
#   'Studio Albums Sales': '17,375,000',
#   'Other LPs Sales': '40,000',
#   'Physical Singles Sales': '250,000'},
#  {'Artist': 'Johnny Hallyday',
#   'Total CSPC': '76,283,000',
#   'Studio Albums Sales': '26,740,000',
#   'Other LPs Sales': '35,156,000',
#   'Physical Singles Sales': '43,740,000'},
#  {'Artist': 'Sade',
#   'Total CSPC': '76,029,000',
#   'Studio Albums Sales': '51,560,000',
#   'Other LPs Sales': '18,565,000',
#   'Physical Singles Sales': '6,270,000'},
#  {'Artist': 'John Lennon',
#   'Total CSPC': '74,738,000',
#   'Studio Albums Sales': '31,420,000',
#   'Other LPs Sales': '30,759,000',
#   'Physical Singles Sales': '26,780,000'},
#  {'Artist': 'Shakira',
#   'Total CSPC': '74,098,000',
#   'Studio Albums Sales': '34,780,000',
#   'Other LPs Sales': '6,620,000',
#   'Physical Singles Sales': '8,460,000'},
#  {'Artist': 'Cher',
#   'Total CSPC': '74,074,000',
#   'Studio Albums Sales': '34,825,000',
#   'Other LPs Sales': '21,889,000',
#   'Physical Singles Sales': '46,220,000'},
#  {'Artist': 'Supertramp',
#   'Total CSPC': '72,444,000',
#   'Studio Albums Sales': '48,540,000',
#   'Other LPs Sales': '17,999,000',
#   'Physical Singles Sales': '10,070,000'},
#  {'Artist': 'The Weeknd',
#   'Total CSPC': '69,533,000',
#   'Studio Albums Sales': '7,215,000',
#   'Other LPs Sales': '3,323,000',
#   'Physical Singles Sales': '90,000'},
#  {'Artist': 'Michael Buble',
#   'Total CSPC': '69,119,000',
#   'Studio Albums Sales': '47,800,000',
#   'Other LPs Sales': '6,344,000',
#   'Physical Singles Sales': '770,000'},
#  {'Artist': 'Usher',
#   'Total CSPC': '68,157,000',
#   'Studio Albums Sales': '36,160,000',
#   'Other LPs Sales': '2,201,000',
#   'Physical Singles Sales': '12,040,000'},
#  {'Artist': 'Ariana Grande',
#   'Total CSPC': '64,489,000',
#   'Studio Albums Sales': '6,005,000',
#   'Other LPs Sales': '681,000',
#   'Physical Singles Sales': '110,000'},
#  {'Artist': 'Oasis',
#   'Total CSPC': '63,704,000',
#   'Studio Albums Sales': '41,050,000',
#   'Other LPs Sales': '10,046,000',
#   'Physical Singles Sales': '11,420,000'},
#  {'Artist': 'Meat Loaf',
#   'Total CSPC': '62,691,000',
#   'Studio Albums Sales': '48,300,000',
#   'Other LPs Sales': '9,565,000',
#   'Physical Singles Sales': '10,850,000'},
#  {'Artist': 'Katy Perry',
#   'Total CSPC': '62,332,000',
#   'Studio Albums Sales': '15,880,000',
#   'Other LPs Sales': '300,000',
#   'Physical Singles Sales': '870,000'},
#  {'Artist': 'Ayumi Hamasaki',
#   'Total CSPC': '61,840,000',
#   'Studio Albums Sales': '21,810,000',
#   'Other LPs Sales': '19,339,000',
#   'Physical Singles Sales': '25,980,000'},
#  {'Artist': 'Bad Bunny',
#   'Total CSPC': '61,656,000',
#   'Studio Albums Sales': '245,000',
#   'Other LPs Sales': '60,000',
#   'Physical Singles Sales': '0'},
#  {'Artist': 'One Direction',
#   'Total CSPC': '61,471,000',
#   'Studio Albums Sales': '23,900,000',
#   'Other LPs Sales': '6,350,000',
#   'Physical Singles Sales': '120,000'},
#  {'Artist': 'Enrique Iglesias',
#   'Total CSPC': '61,311,000',
#   'Studio Albums Sales': '33,900,000',
#   'Other LPs Sales': '5,300,000',
#   'Physical Singles Sales': '8,900,000'},
#  {'Artist': 'Crosby, Stills & Nash',
#   'Total CSPC': '60,995,000',
#   'Studio Albums Sales': '34,420,000',
#   'Other LPs Sales': '21,902,000',
#   'Physical Singles Sales': '8,380,000'},
#  {'Artist': 'Black Eyed Peas',
#   'Total CSPC': '60,729,000',
#   'Studio Albums Sales': '33,350,000',
#   'Other LPs Sales': '251,000',
#   'Physical Singles Sales': '6,590,000'},
#  {'Artist': 'Jackson 5 & The Jacksons',
#   'Total CSPC': '59,809,000',
#   'Studio Albums Sales': '26,400,000',
#   'Other LPs Sales': '19,027,000',
#   'Physical Singles Sales': '31,160,000'},
#  {'Artist': 'Alanis Morissette',
#   'Total CSPC': '58,249,000',
#   'Studio Albums Sales': '47,065,000',
#   'Other LPs Sales': '6,951,000',
#   'Physical Singles Sales': '3,340,000'},
#  {'Artist': 'Nickelback',
#   'Total CSPC': '57,656,000',
#   'Studio Albums Sales': '40,500,000',
#   'Other LPs Sales': '1,824,000',
#   'Physical Singles Sales': '3,020,000'},
#  {'Artist': 'Christina Aguilera',
#   'Total CSPC': '57,041,000',
#   'Studio Albums Sales': '30,400,000',
#   'Other LPs Sales': '4,375,000',
#   'Physical Singles Sales': '12,740,000'},
#  {'Artist': 'Justin Timberlake',
#   'Total CSPC': '55,877,000',
#   'Studio Albums Sales': '23,490,000',
#   'Other LPs Sales': '1,480,000',
#   'Physical Singles Sales': '5,330,000'},
#  {'Artist': 'Miley Cyrus',
#   'Total CSPC': '55,105,000',
#   'Studio Albums Sales': '23,050,000',
#   'Other LPs Sales': '2,365,000',
#   'Physical Singles Sales': '250,000'},
#  {'Artist': 'Alicia Keys',
#   'Total CSPC': '53,660,000',
#   'Studio Albums Sales': '32,960,000',
#   'Other LPs Sales': '2,524,000',
#   'Physical Singles Sales': '3,690,000'},
#  {'Artist': 'Ozzy Osbourne',
#   'Total CSPC': '53,247,000',
#   'Studio Albums Sales': '39,370,000',
#   'Other LPs Sales': '7,483,000',
#   'Physical Singles Sales': '3,760,000'},
#  {'Artist': 'Norah Jones',
#   'Total CSPC': '53,099,000',
#   'Studio Albums Sales': '43,550,000',
#   'Other LPs Sales': '2,825,000',
#   'Physical Singles Sales': '300,000'},
#  {'Artist': 'Paul Simon',
#   'Total CSPC': '52,690,000',
#   'Studio Albums Sales': '34,390,000',
#   'Other LPs Sales': '11,598,000',
#   'Physical Singles Sales': '12,820,000'},
#  {'Artist': 'Tracy Chapman',
#   'Total CSPC': '52,402,000',
#   'Studio Albums Sales': '43,760,000',
#   'Other LPs Sales': '3,519,000',
#   'Physical Singles Sales': '3,480,000'},
#  {'Artist': 'Boston',
#   'Total CSPC': '50,701,000',
#   'Studio Albums Sales': '41,330,000',
#   'Other LPs Sales': '4,803,000',
#   'Physical Singles Sales': '5,640,000'},
#  {'Artist': "Destiny's Child",
#   'Total CSPC': '50,392,000',
#   'Studio Albums Sales': '32,990,000',
#   'Other LPs Sales': '6,735,000',
#   'Physical Singles Sales': '11,320,000'},
#  {'Artist': 'Spice Girls',
#   'Total CSPC': '50,145,000',
#   'Studio Albums Sales': '37,050,000',
#   'Other LPs Sales': '4,349,000',
#   'Physical Singles Sales': '20,020,000'},
#  {'Artist': 'Avril Lavigne',
#   'Total CSPC': '47,893,000',
#   'Studio Albums Sales': '32,290,000',
#   'Other LPs Sales': '1,206,000',
#   'Physical Singles Sales': '3,510,000'},
#  {'Artist': 'Jennifer Lopez',
#   'Total CSPC': '47,180,000',
#   'Studio Albums Sales': '26,120,000',
#   'Other LPs Sales': '4,811,000',
#   'Physical Singles Sales': '10,760,000'},
#  {'Artist': 'Cranberries',
#   'Total CSPC': '47,146,000',
#   'Studio Albums Sales': '37,650,000',
#   'Other LPs Sales': '3,710,000',
#   'Physical Singles Sales': '4,120,000'},
#  {'Artist': 'NSYNC',
#   'Total CSPC': '45,642,000',
#   'Studio Albums Sales': '37,930,000',
#   'Other LPs Sales': '2,669,000',
#   'Physical Singles Sales': '6,980,000'},
#  {'Artist': 'Imagine Dragons',
#   'Total CSPC': '45,581,000',
#   'Studio Albums Sales': '7,960,000',
#   'Other LPs Sales': '371,000',
#   'Physical Singles Sales': '30,000'},
#  {'Artist': 'Foo Fighters',
#   'Total CSPC': '44,775,000',
#   'Studio Albums Sales': '26,750,000',
#   'Other LPs Sales': '6,207,000',
#   'Physical Singles Sales': '1,430,000'},
#  {'Artist': 'Mannheim Steamroller',
#   'Total CSPC': '44,208,000',
#   'Studio Albums Sales': '33,305,000',
#   'Other LPs Sales': '10,344,000',
#   'Physical Singles Sales': '40,000'},
#  {'Artist': 'Post Malone',
#   'Total CSPC': '42,964,000',
#   'Studio Albums Sales': '1,970,000',
#   'Other LPs Sales': '10,000',
#   'Physical Singles Sales': '50,000'},
#  {'Artist': 'Cream',
#   'Total CSPC': '42,241,000',
#   'Studio Albums Sales': '13,200,000',
#   'Other LPs Sales': '26,093,000',
#   'Physical Singles Sales': '4,260,000'},
#  {'Artist': 'TLC',
#   'Total CSPC': '41,604,000',
#   'Studio Albums Sales': '32,195,000',
#   'Other LPs Sales': '1,920,000',
#   'Physical Singles Sales': '13,120,000'},
#  {'Artist': 'Travis Scott',
#   'Total CSPC': '41,209,000',
#   'Studio Albums Sales': '1,670,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '100,000'},
#  {'Artist': 'Take That',
#   'Total CSPC': '39,477,000',
#   'Studio Albums Sales': '19,930,000',
#   'Other LPs Sales': '14,016,000',
#   'Physical Singles Sales': '9,210,000'},
#  {'Artist': 'Kendrick Lamar',
#   'Total CSPC': '39,096,000',
#   'Studio Albums Sales': '7,530,000',
#   'Other LPs Sales': '115,000',
#   'Physical Singles Sales': '10,000'},
#  {'Artist': 'Kelly Clarkson',
#   'Total CSPC': '39,070,000',
#   'Studio Albums Sales': '21,600,000',
#   'Other LPs Sales': '1,460,000',
#   'Physical Singles Sales': '2,200,000'},
#  {'Artist': 'Selena Gomez',
#   'Total CSPC': '38,194,000',
#   'Studio Albums Sales': '5,780,000',
#   'Other LPs Sales': '270,000',
#   'Physical Singles Sales': '80,000'},
#  {'Artist': 'Kylie Minogue',
#   'Total CSPC': '37,664,000',
#   'Studio Albums Sales': '20,320,000',
#   'Other LPs Sales': '7,103,000',
#   'Physical Singles Sales': '19,720,000'},
#  {'Artist': 'Billie Eilish',
#   'Total CSPC': '37,635,000',
#   'Studio Albums Sales': '4,250,000',
#   'Other LPs Sales': '23,000',
#   'Physical Singles Sales': '70,000'},
#  {'Artist': 'Sam Smith',
#   'Total CSPC': '36,239,000',
#   'Studio Albums Sales': '6,525,000',
#   'Other LPs Sales': '25,000',
#   'Physical Singles Sales': '100,000'},
#  {'Artist': 'Xuxa',
#   'Total CSPC': '35,949,000',
#   'Studio Albums Sales': '22,626,000',
#   'Other LPs Sales': '12,436,000',
#   'Physical Singles Sales': '80,000'},
#  {'Artist': 'No Doubt',
#   'Total CSPC': '35,898,000',
#   'Studio Albums Sales': '25,730,000',
#   'Other LPs Sales': '6,058,000',
#   'Physical Singles Sales': '4,910,000'},
#  {'Artist': 'Juice Wrld',
#   'Total CSPC': '35,114,000',
#   'Studio Albums Sales': '623,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '0'},
#  {'Artist': 'Amy Winehouse',
#   'Total CSPC': '34,999,000',
#   'Studio Albums Sales': '23,180,000',
#   'Other LPs Sales': '2,411,000',
#   'Physical Singles Sales': '580,000'},
#  {'Artist': 'Lana Del Rey',
#   'Total CSPC': '33,385,000',
#   'Studio Albums Sales': '10,255,000',
#   'Other LPs Sales': '825,000',
#   'Physical Singles Sales': '220,000'},
#  {'Artist': 'Dua Lipa',
#   'Total CSPC': '32,554,000',
#   'Studio Albums Sales': '1,270,000',
#   'Other LPs Sales': '12,000',
#   'Physical Singles Sales': '40,000'},
#  {'Artist': 'Evanescence',
#   'Total CSPC': '32,378,000',
#   'Studio Albums Sales': '22,440,000',
#   'Other LPs Sales': '2,755,000',
#   'Physical Singles Sales': '2,170,000'},
#  {'Artist': 'Dido',
#   'Total CSPC': '32,028,000',
#   'Studio Albums Sales': '26,630,000',
#   'Other LPs Sales': '420,000',
#   'Physical Singles Sales': '5,320,000'},
#  {'Artist': 'Shawn Mendes',
#   'Total CSPC': '31,243,000',
#   'Studio Albums Sales': '2,913,000',
#   'Other LPs Sales': '121,000',
#   'Physical Singles Sales': '60,000'},
#  {'Artist': 'Carrie Underwood',
#   'Total CSPC': '30,793,000',
#   'Studio Albums Sales': '18,050,000',
#   'Other LPs Sales': '839,000',
#   'Physical Singles Sales': '500,000'},
#  {'Artist': 'Arctic Monkeys',
#   'Total CSPC': '30,719,000',
#   'Studio Albums Sales': '12,255,000',
#   'Other LPs Sales': '585,000',
#   'Physical Singles Sales': '770,000'},
#  {'Artist': 'James Blunt',
#   'Total CSPC': '29,877,000',
#   'Studio Albums Sales': '20,440,000',
#   'Other LPs Sales': '1,020,000',
#   'Physical Singles Sales': '2,130,000'},
#  {'Artist': 'Gorillaz',
#   'Total CSPC': '27,915,000',
#   'Studio Albums Sales': '14,830,000',
#   'Other LPs Sales': '1,240,000',
#   'Physical Singles Sales': '2,110,000'},
#  {'Artist': 'Blackpink',
#   'Total CSPC': '26,826,000',
#   'Studio Albums Sales': '3,005,000',
#   'Other LPs Sales': '1,069,000',
#   'Physical Singles Sales': '350,000'},
#  {'Artist': 'Demi Lovato',
#   'Total CSPC': '26,625,000',
#   'Studio Albums Sales': '4,480,000',
#   'Other LPs Sales': '35,000',
#   'Physical Singles Sales': '50,000'},
#  {'Artist': 'BjÃ¶rk',
#   'Total CSPC': '26,296,000',
#   'Studio Albums Sales': '19,730,000',
#   'Other LPs Sales': '4,372,000',
#   'Physical Singles Sales': '2,620,000'},
#  {'Artist': 'Avicii',
#   'Total CSPC': '26,044,000',
#   'Studio Albums Sales': '2,200,000',
#   'Other LPs Sales': '170,000',
#   'Physical Singles Sales': '250,000'},
#  {'Artist': 'Cardi B',
#   'Total CSPC': '23,140,000',
#   'Studio Albums Sales': '361,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '20,000'},
#  {'Artist': 'Fugees',
#   'Total CSPC': '23,106,000',
#   'Studio Albums Sales': '17,310,000',
#   'Other LPs Sales': '1,348,000',
#   'Physical Singles Sales': '7,160,000'},
#  {'Artist': 'Ms. Lauryn Hill',
#   'Total CSPC': '22,738,000',
#   'Studio Albums Sales': '15,610,000',
#   'Other LPs Sales': '1,734,000',
#   'Physical Singles Sales': '3,660,000'},
#  {'Artist': 'Harry Styles',
#   'Total CSPC': '22,692,000',
#   'Studio Albums Sales': '3,245,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '30,000'},
#  {'Artist': 'Renaud',
#   'Total CSPC': '22,544,000',
#   'Studio Albums Sales': '13,230,000',
#   'Other LPs Sales': '7,667,000',
#   'Physical Singles Sales': '2,660,000'},
#  {'Artist': 'Gwen Stefani',
#   'Total CSPC': '21,496,000',
#   'Studio Albums Sales': '12,060,000',
#   'Other LPs Sales': '154,000',
#   'Physical Singles Sales': '3,130,000'},
#  {'Artist': 'Charlie Puth',
#   'Total CSPC': '20,291,000',
#   'Studio Albums Sales': '1,128,000',
#   'Other LPs Sales': '85,000',
#   'Physical Singles Sales': '10,000'},
#  {'Artist': 'Macklemore',
#   'Total CSPC': '19,478,000',
#   'Studio Albums Sales': '3,225,000',
#   'Other LPs Sales': '45,000',
#   'Physical Singles Sales': '80,000'},
#  {'Artist': 'Aaliyah',
#   'Total CSPC': '18,661,000',
#   'Studio Albums Sales': '12,200,000',
#   'Other LPs Sales': '3,174,000',
#   'Physical Singles Sales': '6,350,000'},
#  {'Artist': 'Lin-Manuel Miranda',
#   'Total CSPC': '18,634,000',
#   'Studio Albums Sales': '4,977,000',
#   'Other LPs Sales': '591,000',
#   'Physical Singles Sales': '10,000'},
#  {'Artist': 'Doja Cat',
#   'Total CSPC': '18,277,000',
#   'Studio Albums Sales': '201,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '10,000'},
#  {'Artist': 'The Yardbirds',
#   'Total CSPC': '16,788,000',
#   'Studio Albums Sales': '3,155,000',
#   'Other LPs Sales': '11,630,000',
#   'Physical Singles Sales': '5,340,000'},
#  {'Artist': 'Meghan Trainor',
#   'Total CSPC': '16,724,000',
#   'Studio Albums Sales': '2,854,000',
#   'Other LPs Sales': '140,000',
#   'Physical Singles Sales': '20,000'},
#  {'Artist': 'Little Mix',
#   'Total CSPC': '16,587,000',
#   'Studio Albums Sales': '3,670,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '130,000'},
#  {'Artist': 'SZA',
#   'Total CSPC': '16,006,000',
#   'Studio Albums Sales': '463,000',
#   'Other LPs Sales': '85,000',
#   'Physical Singles Sales': '20,000'},
#  {'Artist': 'Fergie',
#   'Total CSPC': '14,946,000',
#   'Studio Albums Sales': '6,450,000',
#   'Other LPs Sales': '25,000',
#   'Physical Singles Sales': '750,000'},
#  {'Artist': 'Lorde',
#   'Total CSPC': '14,271,000',
#   'Studio Albums Sales': '3,300,000',
#   'Other LPs Sales': '100,000',
#   'Physical Singles Sales': '0'},
#  {'Artist': 'Will.i.am',
#   'Total CSPC': '14,160,000',
#   'Studio Albums Sales': '950,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '750,000'},
#  {'Artist': 'Olivia Rodrigo',
#   'Total CSPC': '13,162,000',
#   'Studio Albums Sales': '1,165,000',
#   'Other LPs Sales': '2,000',
#   'Physical Singles Sales': '10,000'},
#  {'Artist': 'Lil Nas X',
#   'Total CSPC': '12,630,000',
#   'Studio Albums Sales': '58,000',
#   'Other LPs Sales': '0',
#   'Physical Singles Sales': '0'},
#  {'Artist': 'Carly Rae Jepsen',
#   'Total CSPC': '11,566,000',
#   'Studio Albums Sales': '1,777,000',
#   'Other LPs Sales': '82,000',
#   'Physical Singles Sales': '130,000'},
#  {'Artist': 'Buffalo Springfield',
#   'Total CSPC': '11,306,000',
#   'Studio Albums Sales': '2,885,000',
#   'Other LPs Sales': '6,698,000',
#   'Physical Singles Sales': '1,980,000'},
#  {'Artist': 'Lewis Capaldi',
#   'Total CSPC': '10,443,000',
#   'Studio Albums Sales': '738,000',
#   'Other LPs Sales': '3,000',
#   'Physical Singles Sales': '40,000'},
#  {'Artist': 'Blind Faith',
#   'Total CSPC': '10,093,000',
#   'Studio Albums Sales': '5,395,000',
#   'Other LPs Sales': '4,363,000',
#   'Physical Singles Sales': '90,000'}]

# %%
# Creamos un DataFrame a partir de la lista de datos
df = pd.DataFrame(data)

# Mostramos el DataFrame
print(df)
# Out:
#                   Artist   Total CSPC Studio Albums Sales Other LPs Sales  \
# 0            The Beatles  421,855,000         160,650,000     203,392,000
# 1        Michael Jackson  336,644,000         182,600,000     101,997,000
# 2          Elvis Presley  320,348,000          53,150,000     212,309,000
# 3                  Queen  277,454,000          90,230,000     139,348,000
# 4                Madonna  246,817,000         146,450,000      64,420,000
# ..                   ...          ...                 ...             ...
# 166            Lil Nas X   12,630,000              58,000               0
# 167     Carly Rae Jepsen   11,566,000           1,777,000          82,000
# 168  Buffalo Springfield   11,306,000           2,885,000       6,698,000
# 169        Lewis Capaldi   10,443,000             738,000           3,000
# 170          Blind Faith   10,093,000           5,395,000       4,363,000
#
#     Physical Singles Sales Digital Singles Sales Sales Update  \
# 0              116,080,000            35,230,000     03/01/17
# 1               79,350,000            79,930,000     09/27/17
# 2              135,210,000            37,470,000     09/01/18
# 3               49,960,000            59,650,000     01/25/20
# 4               75,210,000            42,100,000     08/13/17
# ..                     ...                   ...          ...
# 166                      0             3,600,000     08/16/22
# 167                130,000            31,940,000     12/14/22
# 168              1,980,000             3,550,000     05/15/21
# 169                 40,000             3,420,000     08/31/21
# 170                 90,000             1,300,000     09/21/22
#
#       Streams EAS (Update)
# 0    17,705,000 (03/07/23)
# 1    16,252,000 (03/08/23)
# 2     8,707,000 (03/07/23)
# 3    23,937,000 (03/07/23)
# 4     7,068,000 (03/09/23)
# ..                     ...
# 166  12,032,000 (03/08/23)
# 167   4,878,000 (03/08/23)
# 168     603,000 (02/15/23)
# 169   9,176,000 (03/02/23)
# 170     114,000 (02/01/23)
#
# [171 rows x 8 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv('Best_Sellings_All_Time.csv', sep='|')
