# %% [markdown]
# # Limpieza de datos del DataFrame de la revista Rolling Stones

# %% [markdown]
# Extraido de: https://www.kaggle.com/datasets/marshuu/best-artists-dataset-grammys-billboard-rs

# %%
import pandas as pd

RS_magazine = pd.read_csv("..\data\\best artists_RS.csv")
RS_magazine
# Out:
#     Rolling Stone Magazine Rank                       Artist  \
# 0                             1                  The Beatles
# 1                             2                    Bob Dylan
# 2                             3                Elvis Presley
# 3                             4           The Rolling Stones
# 4                             5                  Chuck Berry
# ..                          ...                          ...
# 95                           96  Diana Ross and the Supremes
# 96                           97                       R.E.M.
# 97                           98              Curtis Mayfield
# 98                           99                 Carl Perkins
# 99                          100                Talking Heads
#
#    Racial/Ethnic group  Main Grammy awards  Main Grammy Nominations  \
# 0       White/European                   2                       10
# 1       White/European                   1                        4
# ...

# %%
RS_magazine.describe(include='all')
# Out:
#         Rolling Stone Magazine Rank       Artist Racial/Ethnic group  \
# count                    100.000000          100                 100
# unique                          NaN          100                   6
# top                             NaN  The Beatles      White/European
# freq                            NaN            1                  62
# mean                      50.500000          NaN                 NaN
# std                       29.011492          NaN                 NaN
# min                        1.000000          NaN                 NaN
# 25%                       25.750000          NaN                 NaN
# 50%                       50.500000          NaN                 NaN
# 75%                       75.250000          NaN                 NaN
# max                      100.000000          NaN                 NaN
#
#         Main Grammy awards  Main Grammy Nominations  Total Awards  \
# count           100.000000               100.000000    100.000000
# ...

# %%
'''
De este dataframe solo nos interesa la columna de las veces que han estado en los primeros puestos de UK y lo que es en si la clasificación de la revista Rolling Stone.
El resto de columnas podemos omitirlas.
'''

RS_magazine.drop(['Racial/Ethnic group', 'Main Grammy awards', 'Main Grammy Nominations', 'Total Awards', 'Total Nominations'], axis=1, inplace=True)
RS_magazine.set_index('Rolling Stone Magazine Rank', inplace=True)

# %%
RS_magazine
# Out:
#                                                   Artist  UK number 1's
# Rolling Stone Magazine Rank
# 1                                            The Beatles             17
# 2                                              Bob Dylan              1
# 3                                          Elvis Presley             21
# 4                                     The Rolling Stones              8
# 5                                            Chuck Berry              1
# ...                                                  ...            ...
# 96                           Diana Ross and the Supremes              1
# 97                                                R.E.M.              0
# 98                                       Curtis Mayfield              0
# 99                                          Carl Perkins              0
# 100                                        Talking Heads              0
#
# [100 rows x 2 columns]

# %%
#RS_magazine.to_csv('RS_magazine_limpio.csv')
